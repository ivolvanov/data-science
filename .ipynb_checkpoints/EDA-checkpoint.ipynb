# %%
import pandas as pd
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

recipe_cooktime = pd.read_csv('./exp/recipe_cooktime.csv')
recipe_ingredient = pd.read_csv('./exp/recipe_ingredient.csv')
recipe_nutrition = pd.read_csv('./exp/recipe_nutrition.csv')

# %%
recipe_cooktime['total_time'] = recipe_cooktime['prep_min']+recipe_cooktime['cook_min']+recipe_cooktime['stnd_min']
cooktime_box_plot = sns.displot(x = recipe_cooktime['total_time'], kind="kde")

# %%
asd = pd.DataFrame(recipe_ingredient.groupby(["recipe_id"])["ingredient_id"].count())

# %%
recipe_nutrition.sort_values("recipe_id",inplace = True)

asd["calories"] = recipe_nutrition['calories']
recipe_nutrition.head(10)
# Out:
#      recipe_id  protein  carbo  alcohol  total_fat  sat_fat  cholestrl  \
# 559        886      0.0  35.44      0.0       0.00     0.00       0.00
# 540        866      0.0  36.40      0.0       0.25     0.00       0.00
# 572        899      0.0   2.42      0.0       0.00     0.00       0.00
# 573        900      0.0   4.16      0.0       0.00     0.00       0.00
# 574        901      0.0  26.00      0.0       0.00     0.00       0.00
# 575        902      0.0  11.28      0.0       0.00     0.00       0.00
# 577        904      0.0   0.00      0.0      11.06     2.01       5.03
# 534        860      0.0   0.45      0.0       0.05     0.00       0.00
# 556        883      0.0  38.44      0.0       0.00     0.02       0.00
# 558        885      0.0   0.00      0.0       0.00     0.00       0.00
#
#      sodium  iron  vitamin_c  vitamin_a  fiber  pcnt_cal_carb  pcnt_cal_fat  \
# 559   37.50  0.24       0.00       0.00    0.0         100.00          0.00
# ...

# %%
asd
# Out:
#            ingredient_id  calories
# recipe_id
# 214                    9    199.97
# 215                    6    267.50
# 216                    5    192.44
# 217                    3      6.10
# 218                    8    404.77
# ...                  ...       ...
# 1427                   7       NaN
# 1428                   3       NaN
# 1429                   1       NaN
# 1432                  12       NaN
# 1436                   2       NaN
#
# [843 rows x 2 columns]
